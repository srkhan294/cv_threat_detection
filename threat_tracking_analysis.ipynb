# %%
# !pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2 --index-url https://download.pytorch.org/whl/cpu
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
import cv2
import matplotlib.pyplot as plt
from collections import defaultdict
import numpy as np

# %% [markdown]
# ## Object detection and trail using yolov8n

# %%
# Load the YOLOv8 model
model = YOLO("yolov8n.pt")

# Open the video file
video_path = "videoplayback.mp4"
cap = cv2.VideoCapture(video_path)

# Store the track history
track_history = defaultdict(list)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model.track(frame,conf=0.4,persist=True,agnostic_nms=True,classes=[0])
        annotated_frame = results[0].plot() # Visualize the results on the frame
        try:
            ids= results[0].boxes.id.int().cpu().tolist()
            boxes= results[0].boxes.xywh.cpu()

            for box, id in zip(boxes,ids):
                x,y,w,h=box
                track=track_history[id]
                track.append((float(x),float(y)))  # x, y center point
                points=np.hstack(track).astype(np.int32).reshape((-1,1,2))
                if len(points)>30:
                    points=points[20:]            
                cv2.polylines(annotated_frame,[points],isClosed=False,thickness=10,color=(240,240,240))
        except: pass
        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)
        
        
        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Object tracking using deepSORT

# %%
from deep_sort import nn_matching
from deep_sort.detection import Detection
from deep_sort.tracker import Tracker
import cv2 
from ultralytics import YOLO
import numpy as np
import matplotlib.pyplot as plt
from tools import generate_detections_ as gdet

# %%
model_d='mars-small128.pb'
metric=nn_matching.NearestNeighborDistanceMetric(metric='cosine',matching_threshold=0.4)
tracker=Tracker(metric)
encoder = gdet.create_box_encoder(model_d, batch_size=1)

# Load the YOLOv8 model
model = YOLO("yolov8n.pt")

# Open the capeo file
video_path = "videoplayback.mp4"
cap = cv2.VideoCapture(video_path)

while cap.isOpened():
    success, frame= cap.read()

    if success:
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = int(cap.get(cv2.CAP_PROP_FPS))

        results=model.track(frame,conf=0.4,persist=True,agnostic_nms=True,show=True,classes=[0])
        try:
            ids= results[0].boxes.id.int().cpu().tolist()
            boxes= results[0].boxes
            for box, id in zip(boxes,ids):
                cls=results[0].names[int(box.cls.item())]
                x,y,w,h=np.array(box.xywh[0])
                prob=box.conf
                print(cls)
                features=encoder(frame,boxes)
                detections = [Detection(bbox, score, class_name, feature) for bbox, score, class_name, feature in 
                              zip(boxes, prob, cls, features)]
            break
        except:
             break

        

        if cv2.waitKey(1) & 0xFF == ord("q"):
                break
    else:
        print('Failed!!')
    

cap.release()
cv2.destroyAllWindows()

# %%
from PIL import Image
import cv2 
import ultralytics
from ultralytics import YOLO
import numpy as np
import matplotlib.pyplot as plt
from tracker import Tracker
import random

# %%
# Load the YOLOv8 model
detection_model = YOLO("yolov8n.pt")
pose_model=YOLO('yolov8n-pose.pt')

# Open the capeo file
video_path = "videoplayback.mp4"
cap = cv2.VideoCapture(video_path)

tracker=Tracker()

colors=[(random.randint(0,255),random.randint(0,255),random.randint(0,255)) for j in range(10) ]

while cap.isOpened():
     success, frame= cap.read()
     if success:
          results=detection_model(frame,conf=0.3,classes=[0])
          pose_results=pose_model(frame,conf=0.3,classes=[0])
          detections=[]
          try:
             for result,pose in zip(results,pose_results):
               for r in result.boxes.data.tolist():
                    x1,y1,x2,y2,probs,cls=r
                    x1=int(x1)
                    y1=int(y1)
                    x2=int(x2)
                    y2=int(y2)
                    cls=int(cls)
                    detections.append([x1,y1,x2,y2,probs])
               tracker.update(frame,detections)
               for track in tracker.tracks:
                    x1,y1,x2,y2=track.bbox
                    id=track.track_id
                    cv2.rectangle(frame,(int(x1) , int(y1)),(int(x2) , int(y2)), 
                                  (colors[id % len(colors)]),3)
          except Exception as e:
               cap.release()
               cv2.destroyAllWindows()
               raise e

          cv2.imshow("YOLOv8 Inference", frame)
          #success,frame=cap.read()

          if cv2.waitKey(1) & 0xFF == ord("q"):
                    break
     else:
          print('Failed!!')
cap.release()
cv2.destroyAllWindows()

# %%
# Load the YOLOv8 model
detection_model = YOLO("yolov8n.pt")
pose_model=YOLO('yolov8n-pose.pt')

# %%
t=np.array([[4.1655e+02, 3.8043e+02, 9.2585e-01],
        [4.2234e+02, 3.7166e+02, 6.4439e-01],
        [4.0699e+02, 3.7212e+02, 9.2182e-01],
        [0.0000e+00, 0.0000e+00, 3.3340e-01],
        [3.8414e+02, 3.7460e+02, 8.9738e-01],
        [4.1617e+02, 4.3102e+02, 9.6508e-01],
        [3.5874e+02, 4.3142e+02, 9.9606e-01],
        [4.1607e+02, 5.1359e+02, 8.0344e-01],
        [3.4776e+02, 5.0876e+02, 9.8815e-01],
        [4.3893e+02, 5.3288e+02, 7.5023e-01],
        [4.1230e+02, 5.0540e+02, 9.6717e-01],
        [4.0255e+02, 5.7523e+02, 9.8760e-01],
        [3.7483e+02, 5.7878e+02, 9.9580e-01],
        [3.7855e+02, 6.8531e+02, 9.7513e-01],
        [4.1787e+02, 6.9362e+02, 9.9192e-01],
        [3.2192e+02, 7.7031e+02, 9.3976e-01],
        [4.2578e+02, 7.8576e+02, 9.7017e-01]])
def estimate_threat(kypts):
    kypts=kypts.tolist()
    kypts=[[x,y,p] if p>0.6 else [0,0,p] for x,y,p in kypts]
    re,le=kypts[2][:2],kypts[1][:2]
    rs,ls=kypts[6][:2],kypts[5][:2]
    rw,lw=kypts[10][:2],kypts[9][:2]
    avg_e=(np.mean((re[0],le[0])),np.mean((re[1],le[1])))
    avg_s=(np.mean((rs[0],ls[0])),np.mean((rs[1],ls[1])))
    print(avg_e,avg_s,rw,lw)
    if avg_s[1]!=0:
        max_wrist_coord=np.max((rw[1],lw[1]))
        if max_wrist_coord!=0 and max_wrist_coord<avg_s[1]:            
            print('threat')
            return True
        else:
            return False
    else:
        return False
    
estimate_threat(t)

# %%
np.mean((2,3.9))

# %%
# Open the capeo file
video_path = "videoplayback.mp4"
cap = cv2.VideoCapture(0)
while cap.isOpened():
     success, frame= cap.read()
     if success:
          results=pose_model(frame,conf=0.3,classes=[0],show=True)
          pose=[]
          try:
             for result in results:
                   for r in result.keypoints.data:
                         threat=estimate_threat(r)
                         print(threat)                       
          except Exception as e:
               cap.release()
               cv2.destroyAllWindows()
               raise e

          # cv2.imshow("YOLOv8 Inference", frame)
          
          if cv2.waitKey(1) & 0xFF == ord("q"):
                    break
     else:
          print('Failed!!')
cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
vector1 = np.array([0, 0])
vector2 = np.array([0, 0])

angle_between(vector1, vector2)

# %%
relative_pos(174.7609405517578,174.7609405517578,364.7063293457031)

# %%
# def relative_pos(o,p2,p3):
#     p2=np.array(o)-np.array(p2)
#     p3=np.array(o)-np.array(p3)
#     return (p2,p3)

# def angle_between(v1, v2):
#   cos_theta = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))
#   return np.degrees(np.arccos(np.clip(cos_theta, -1.0, 1.0)))

# def estimate_threat(kypts):
#     flag=False
#     kypts=kypts.tolist()
#     kypts=[[x,y,p] if p>0.4 else [0,0,p] for x,y,p in kypts]
#     rs,ls=kypts[6][:2],kypts[5][:2] #shoulders c,y coord
#     rw,lw=kypts[10][:2],kypts[9][:2] #wrist x,y coord
#     rel,lel=kypts[8][:2],kypts[7][:2]
#     avg_s=(np.mean((rs[0],ls[0])),np.mean((rs[1],ls[1])))
#     avg_el=(np.mean((rel[0],lel[0])),np.mean((rel[1],lel[1])))
#     if (avg_el[1]!=0)&(avg_s[1]!=0):
#         elb_y=[rel[1],lel[1]]
#         wrist_y=[rw[1],lw[1]]
#         min_wrist_coord=min(wrist_y)
#         min_ind=wrist_y.index(min_wrist_coord)
#         max_wrist_coord=max(wrist_y)
#         max_ind=wrist_y.index(max_wrist_coord)
#         angle=0
#         if max_wrist_coord!=0:
#             if (elb_y[min_ind]!=0)&(min_wrist_coord!=0) | (elb_y[max_ind]!=0)&(max_wrist_coord!=0):
#                 if min_wrist_coord<=elb_y[min_ind]:
#                     if min_ind==0:
#                         p1,q1=relative_pos(rel,rw,avg_s)
#                         angle=angle_between(q1,p1)
#                     else:
#                         p1,q1=relative_pos(lel,lw,avg_s)
#                         angle=angle_between(q1,p1)
#                     if (angle>90):
#                         print('threat1',angle, wrist_y, elb_y, min_ind)
#                         flag=True
#                         return flag
#                 if max_wrist_coord<=elb_y[max_ind]:
#                     if max_ind==0:
#                         p1,q1=relative_pos(rel,rw,avg_s)
#                         angle=angle_between(q1,p1)
#                     else:
#                         p1,q1=relative_pos(lel,lw,avg_s)
#                         angle=angle_between(q1,p1)
#                     if (angle>90):
#                         print('threat2',angle, wrist_y, elb_y, max_ind)
#                         flag=True
#                         return flag  
#     return flag

# '''threat2 97.86680876173493 [0, 454.80377197265625] [0, 457.8333435058594] 1'''

# %%
'''
Function to create a local coordinate system
'''
def relative_pos(o,p2,p3):
    p2=np.array(o)-np.array(p2)
    p3=np.array(o)-np.array(p3)
    return (p2,p3)

'''
Function to calculate angle between two vectors
'''
def angle_between(v1, v2):
  cos_theta = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))
  return np.degrees(np.arccos(np.clip(cos_theta, -1.0, 1.0)))

'''
Function to estimate whether a person is a threat or not
based on location of his joints
'''
def estimate_threat(kypts):
    flag=False
    kypts=[[x,y] if p>0.5 else [0,0] for x,y,p in kypts]
    rs,ls=kypts[6],kypts[5] #shoulders c,y coord
    rw,lw=kypts[10],kypts[9] #wrist x,y coord
    rel,lel=kypts[8],kypts[7] #elbow x,y coord
    
    '''
    Check if any of the wrist is raised above the elbow level and the angle 
    formed between the shoulder and hand of the respective hand is greater than 90
    then we may consider it as a threating gesture.
    '''
    if (rel!=[0,0]) & (rs!=[0,0]) & (rw!=[0,0]):
        if rw[1]<=rel[1]:
            p1,q1=relative_pos(rel,rw,rs)
            angle=angle_between(q1,p1)
            if angle>90:
                flag=True
                return flag
    if (lel!=[0,0]) & (ls!=[0,0]) & (lw!=[0,0]):
        if lw[1]<=lel[1]:
            p1,q1=relative_pos(lel,lw,ls)
            angle=angle_between(q1,p1)
            if angle>90:
                flag=True
                return flag
    return flag

# %%
# Load the YOLOv8-pose model for object detection & gathering coordinate data of joints
pose_model=YOLO('yolov8n-pose.pt')

# Create a tracker object of DeepSORT
tracker=Tracker()

# List of random colors (BGR)
colors=[(random.randint(0,255),random.randint(0,255),random.randint(0,200)) for j in range(10)]

# Load input file
video_path = "robbery2.mp4"
cap = cv2.VideoCapture(0)

while cap.isOpened():
     success, frame= cap.read()
     if success:
          results=pose_model(frame,conf=0.2,classes=[0],show=False)
          detections=[]
          threats=[]
          try:
             for result in results:
               for r,pr in zip(result.boxes.data.tolist(),result.keypoints.data.tolist()):
                    x1,y1,x2,y2,probs,cls=r
                    x1=int(x1)
                    y1=int(y1)
                    x2=int(x2)
                    y2=int(y2)
                    cls=int(cls)
                    detections.append([x1,y1,x2,y2,probs])
                    threats.append(estimate_threat(pr))
               tracker.update(frame,detections)
               for track,threat in zip(tracker.tracks,threats):
                    x1,y1,x2,y2=track.bbox
                    id=track.track_id
                    font = cv2.FONT_HERSHEY_SIMPLEX
                    if threat:
                         cv2.rectangle(frame,(int(x1) , int(y1)),(int(x2) , int(y2)), 
                                  (0,0,255),3)
                         cv2.putText(frame,'THREAT',(int(x1) , int(y1)),font,1,(0,0,255),3,cv2.LINE_AA)
                    else:
                         cv2.rectangle(frame,(int(x1) , int(y1)),(int(x2) , int(y2)), 
                                  (colors[id % len(colors)]),3)
                         cv2.putText(frame,'SAFE',(int(x1) , int(y1)),font,1,(0,255,0),3,cv2.LINE_AA)
          except Exception as e:
               cap.release()
               cv2.destroyAllWindows()
               raise e

          cv2.imshow("YOLOv8 Inference", frame)

          if cv2.waitKey(1) & 0xFF == ord("q"):
                    break
     else:
          print('Failed!!')
cap.release()
cv2.destroyAllWindows()

# %%
from PIL import Image
import cv2 
import ultralytics
from ultralytics import YOLO
import numpy as np
import matplotlib.pyplot as plt
from tracker import Tracker
import random

'''
Function to create a local coordinate system
'''
def relative_pos(o,p2,p3):
    p2=np.array(o)-np.array(p2)
    p3=np.array(o)-np.array(p3)
    return (p2,p3)

'''
Function to calculate angle between two vectors
'''
def angle_between(v1, v2):
  cos_theta = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))
  return np.degrees(np.arccos(np.clip(cos_theta, -1.0, 1.0)))

'''
Function to estimate whether a person is a threat or not
based on location of his joints
'''
def estimate_threat(kypts):
    flag=False
    kypts=[[x,y] if p>0.5 else [0,0] for x,y,p in kypts]
    rs,ls=kypts[6],kypts[5] #shoulders c,y coord
    rw,lw=kypts[10],kypts[9] #wrist x,y coord
    rel,lel=kypts[8],kypts[7] #elbow x,y coord
    
    '''
    Check if any of the wrist is raised above the elbow level and the angle 
    formed between the shoulder and hand of the respective hand is greater than 90
    then we may consider it as a threating gesture.
    '''
    if (rel!=[0,0]) & (rs!=[0,0]) & (rw!=[0,0]):
        if rw[1]<=rel[1]:
            p1,q1=relative_pos(rel,rw,rs)
            angle=angle_between(q1,p1)
            if angle>90:
                flag=True
                return flag
    if (lel!=[0,0]) & (ls!=[0,0]) & (lw!=[0,0]):
        if lw[1]<=lel[1]:
            p1,q1=relative_pos(lel,lw,ls)
            angle=angle_between(q1,p1)
            if angle>90:
                flag=True
                return flag
    return flag


# Load the YOLOv8-pose model for object detection & gathering coordinate data of joints
pose_model=YOLO('yolov8n-pose.pt')

# Create a tracker object of DeepSORT
tracker=Tracker()

# List of random colors (BGR)
colors=[(random.randint(0,255),random.randint(0,255),random.randint(0,200)) for j in range(10)]

# Load input file
cap = cv2.VideoCapture(0)
success, frame= cap.read()

while cap.isOpened():
     success, frame= cap.read()
     if success:
          results=pose_model(frame,conf=0.2,classes=[0],show=False)
          detections=[]
          font = cv2.FONT_HERSHEY_SIMPLEX
          try:
             for result in results:
               for r,pr in zip(result.boxes.data.tolist(),result.keypoints.data.tolist()):
                    x1,y1,x2,y2,probs,cls=r
                    x1=int(x1)
                    y1=int(y1)
                    x2=int(x2)
                    y2=int(y2)
                    cls=int(cls)
                    detections.append([x1,y1,x2,y2,probs])
                    threat=estimate_threat(pr)
                    if threat:
                        cv2.putText(frame,'THREAT',(int(x1) , int(y1)),font,1,(0,0,255),3,cv2.LINE_AA)
                    else:
                        cv2.putText(frame,'SAFE',(int(x1) , int(y1)),font,1,(0,255,0),3,cv2.LINE_AA)

               tracker.update(frame,detections)
               for track in tracker.tracks:
                    x1,y1,x2,y2=track.bbox
                    id=track.track_id
                    cv2.rectangle(frame,(int(x1) , int(y1)),(int(x2) , int(y2)), 
                            (colors[id % len(colors)]),3)
                         
          except Exception as e:
               cap.release()
               cv2.destroyAllWindows()
               raise e
           
          cv2.imshow("YOLOv8 Inference", frame)

          if cv2.waitKey(1) & 0xFF == ord("q"):
                    break
     else:
          print('Failed!!')
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 227.1ms
# Speed: 5.0ms preprocess, 227.1ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 271.7ms
# Speed: 0.0ms preprocess, 271.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 226.7ms
# Speed: 0.0ms preprocess, 226.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 231.2ms
# Speed: 0.0ms preprocess, 231.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 243.6ms
# Speed: 2.5ms preprocess, 243.6ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 308.0ms
# Speed: 6.1ms preprocess, 308.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 268.4ms
# Speed: 4.0ms preprocess, 268.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 234.3ms
# Speed: 5.3ms preprocess, 234.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 236.3ms
# Speed: 0.0ms preprocess, 236.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 232.0ms
# Speed: 0.0ms preprocess, 232.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 223.4ms
# Speed: 2.0ms preprocess, 223.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.1ms
# Speed: 3.0ms preprocess, 208.1ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 217.7ms
# Speed: 3.0ms preprocess, 217.7ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 238.5ms
# Speed: 0.0ms preprocess, 238.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.2ms
# Speed: 3.0ms preprocess, 211.2ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.5ms
# Speed: 0.0ms preprocess, 212.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.4ms
# Speed: 3.0ms preprocess, 206.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.4ms
# Speed: 3.0ms preprocess, 215.4ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.2ms
# Speed: 2.8ms preprocess, 198.2ms inference, 11.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.1ms
# Speed: 3.0ms preprocess, 204.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.5ms
# Speed: 2.4ms preprocess, 205.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.0ms
# Speed: 0.0ms preprocess, 210.0ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.2ms
# Speed: 3.0ms preprocess, 218.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.5ms
# Speed: 2.1ms preprocess, 190.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.2ms
# Speed: 3.0ms preprocess, 205.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.2ms
# Speed: 4.5ms preprocess, 205.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.5ms
# Speed: 4.0ms preprocess, 195.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.1ms
# Speed: 3.9ms preprocess, 198.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.3ms
# Speed: 4.1ms preprocess, 204.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.2ms
# Speed: 3.3ms preprocess, 191.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.5ms
# Speed: 1.2ms preprocess, 201.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.4ms
# Speed: 2.0ms preprocess, 202.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.3ms
# Speed: 3.6ms preprocess, 207.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.0ms
# Speed: 2.6ms preprocess, 206.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.4ms
# Speed: 2.4ms preprocess, 205.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.5ms
# Speed: 2.7ms preprocess, 207.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.6ms
# Speed: 3.5ms preprocess, 213.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.8ms
# Speed: 4.6ms preprocess, 210.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.4ms
# Speed: 3.1ms preprocess, 214.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.1ms
# Speed: 2.5ms preprocess, 211.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.5ms
# Speed: 0.0ms preprocess, 203.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 240.4ms
# Speed: 2.5ms preprocess, 240.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 278.4ms
# Speed: 2.5ms preprocess, 278.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 242.2ms
# Speed: 3.0ms preprocess, 242.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 234.5ms
# Speed: 3.0ms preprocess, 234.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.1ms
# Speed: 3.0ms preprocess, 211.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.4ms
# Speed: 3.5ms preprocess, 207.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.8ms
# Speed: 4.0ms preprocess, 214.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.6ms
# Speed: 2.1ms preprocess, 209.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.4ms
# Speed: 3.1ms preprocess, 215.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.4ms
# Speed: 2.0ms preprocess, 205.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.4ms
# Speed: 1.9ms preprocess, 191.4ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.7ms
# Speed: 2.8ms preprocess, 193.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.9ms
# Speed: 3.3ms preprocess, 201.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.5ms
# Speed: 2.5ms preprocess, 205.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.4ms
# Speed: 4.6ms preprocess, 212.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.1ms
# Speed: 1.9ms preprocess, 215.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.9ms
# Speed: 4.0ms preprocess, 206.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.0ms
# Speed: 3.0ms preprocess, 206.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.8ms
# Speed: 1.9ms preprocess, 205.8ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 230.4ms
# Speed: 3.8ms preprocess, 230.4ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.9ms
# Speed: 3.0ms preprocess, 209.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.8ms
# Speed: 3.1ms preprocess, 209.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.6ms
# Speed: 0.0ms preprocess, 211.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 205.8ms
# Speed: 3.0ms preprocess, 205.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.6ms
# Speed: 2.0ms preprocess, 209.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.1ms
# Speed: 0.0ms preprocess, 208.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.9ms
# Speed: 0.0ms preprocess, 210.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.9ms
# Speed: 5.2ms preprocess, 213.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.5ms
# Speed: 3.1ms preprocess, 206.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.0ms
# Speed: 2.6ms preprocess, 197.0ms inference, 11.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.6ms
# Speed: 0.0ms preprocess, 213.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.7ms
# Speed: 0.0ms preprocess, 213.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 220.1ms
# Speed: 3.5ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.8ms
# Speed: 2.7ms preprocess, 211.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.6ms
# Speed: 1.7ms preprocess, 211.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.9ms
# Speed: 2.6ms preprocess, 214.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.3ms
# Speed: 0.0ms preprocess, 212.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.7ms
# Speed: 3.4ms preprocess, 204.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.7ms
# Speed: 3.2ms preprocess, 209.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.6ms
# Speed: 3.1ms preprocess, 204.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.6ms
# Speed: 0.0ms preprocess, 211.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.6ms
# Speed: 3.3ms preprocess, 201.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.0ms
# Speed: 3.7ms preprocess, 207.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.0ms
# Speed: 3.5ms preprocess, 207.0ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.8ms
# Speed: 2.7ms preprocess, 208.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.3ms
# Speed: 5.2ms preprocess, 213.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.4ms
# Speed: 3.2ms preprocess, 201.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.7ms
# Speed: 4.1ms preprocess, 214.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.7ms
# Speed: 0.0ms preprocess, 207.7ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.4ms
# Speed: 3.9ms preprocess, 203.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.7ms
# Speed: 3.0ms preprocess, 209.7ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.3ms
# Speed: 0.5ms preprocess, 202.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.9ms
# Speed: 3.5ms preprocess, 209.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.5ms
# Speed: 3.4ms preprocess, 211.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.6ms
# Speed: 4.5ms preprocess, 200.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.2ms
# Speed: 4.9ms preprocess, 211.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.7ms
# Speed: 4.2ms preprocess, 207.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.3ms
# Speed: 1.0ms preprocess, 201.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.2ms
# Speed: 4.7ms preprocess, 204.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.9ms
# Speed: 2.5ms preprocess, 211.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.2ms
# Speed: 3.0ms preprocess, 195.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.2ms
# Speed: 3.9ms preprocess, 208.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.6ms
# Speed: 2.1ms preprocess, 212.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.6ms
# Speed: 4.7ms preprocess, 213.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.3ms
# Speed: 4.0ms preprocess, 212.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.0ms
# Speed: 2.1ms preprocess, 202.0ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.1ms
# Speed: 3.0ms preprocess, 210.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.2ms
# Speed: 2.6ms preprocess, 200.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.7ms
# Speed: 0.0ms preprocess, 208.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.1ms
# Speed: 4.2ms preprocess, 210.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.7ms
# Speed: 2.1ms preprocess, 206.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.8ms
# Speed: 0.0ms preprocess, 207.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.2ms
# Speed: 3.0ms preprocess, 209.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.8ms
# Speed: 2.0ms preprocess, 202.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.1ms
# Speed: 2.4ms preprocess, 210.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 506.4ms
# Speed: 13.6ms preprocess, 506.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.9ms
# Speed: 5.3ms preprocess, 211.9ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.2ms
# Speed: 0.0ms preprocess, 218.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.2ms
# Speed: 3.5ms preprocess, 213.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.8ms
# Speed: 3.6ms preprocess, 207.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.7ms
# Speed: 4.1ms preprocess, 213.7ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.9ms
# Speed: 0.0ms preprocess, 224.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.7ms
# Speed: 0.0ms preprocess, 220.7ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 216.0ms
# Speed: 3.3ms preprocess, 216.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.6ms
# Speed: 0.0ms preprocess, 206.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.0ms
# Speed: 0.0ms preprocess, 211.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.5ms
# Speed: 0.0ms preprocess, 214.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.7ms
# Speed: 3.2ms preprocess, 205.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.7ms
# Speed: 3.0ms preprocess, 205.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.4ms
# Speed: 3.0ms preprocess, 201.4ms inference, 11.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.9ms
# Speed: 3.0ms preprocess, 198.9ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.0ms
# Speed: 2.0ms preprocess, 204.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.2ms
# Speed: 2.0ms preprocess, 201.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.1ms
# Speed: 3.0ms preprocess, 205.1ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.8ms
# Speed: 2.5ms preprocess, 202.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.4ms
# Speed: 3.0ms preprocess, 212.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.3ms
# Speed: 3.0ms preprocess, 211.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.1ms
# Speed: 3.0ms preprocess, 203.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.6ms
# Speed: 3.0ms preprocess, 212.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.5ms
# Speed: 1.5ms preprocess, 218.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.2ms
# Speed: 0.0ms preprocess, 210.2ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.5ms
# Speed: 2.7ms preprocess, 207.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.6ms
# Speed: 3.5ms preprocess, 204.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.1ms
# Speed: 2.0ms preprocess, 210.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.6ms
# Speed: 2.2ms preprocess, 210.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 216.9ms
# Speed: 4.8ms preprocess, 216.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.6ms
# Speed: 3.0ms preprocess, 210.6ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.5ms
# Speed: 3.0ms preprocess, 204.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.0ms
# Speed: 0.0ms preprocess, 206.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.9ms
# Speed: 0.0ms preprocess, 220.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.8ms
# Speed: 3.4ms preprocess, 201.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.9ms
# Speed: 4.1ms preprocess, 207.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.7ms
# Speed: 0.0ms preprocess, 203.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.4ms
# Speed: 2.3ms preprocess, 201.4ms inference, 12.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.4ms
# Speed: 0.0ms preprocess, 218.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.6ms
# Speed: 0.0ms preprocess, 196.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.8ms
# Speed: 1.1ms preprocess, 202.8ms inference, 15.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.8ms
# Speed: 0.0ms preprocess, 203.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.5ms
# Speed: 2.5ms preprocess, 210.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.1ms
# Speed: 2.8ms preprocess, 206.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.7ms
# Speed: 4.4ms preprocess, 208.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.7ms
# Speed: 3.5ms preprocess, 205.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.4ms
# Speed: 1.0ms preprocess, 212.4ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.0ms
# Speed: 2.1ms preprocess, 219.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.6ms
# Speed: 3.5ms preprocess, 222.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.3ms
# Speed: 3.1ms preprocess, 208.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.5ms
# Speed: 3.1ms preprocess, 210.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.4ms
# Speed: 2.4ms preprocess, 203.4ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.1ms
# Speed: 3.0ms preprocess, 227.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.1ms
# Speed: 0.0ms preprocess, 208.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 216.4ms
# Speed: 2.7ms preprocess, 216.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.9ms
# Speed: 3.0ms preprocess, 203.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.6ms
# Speed: 2.4ms preprocess, 208.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.1ms
# Speed: 3.9ms preprocess, 202.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.1ms
# Speed: 2.5ms preprocess, 205.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.4ms
# Speed: 4.0ms preprocess, 206.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.0ms
# Speed: 2.5ms preprocess, 206.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.4ms
# Speed: 3.0ms preprocess, 205.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.1ms
# Speed: 2.8ms preprocess, 203.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.5ms
# Speed: 3.0ms preprocess, 207.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.4ms
# Speed: 2.0ms preprocess, 211.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.2ms
# Speed: 3.5ms preprocess, 200.2ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.4ms
# Speed: 0.0ms preprocess, 215.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.0ms
# Speed: 2.2ms preprocess, 202.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 210.2ms
# Speed: 3.2ms preprocess, 210.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.4ms
# Speed: 4.1ms preprocess, 192.4ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.4ms
# Speed: 5.1ms preprocess, 206.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.9ms
# Speed: 1.0ms preprocess, 204.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.9ms
# Speed: 3.1ms preprocess, 204.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.8ms
# Speed: 2.1ms preprocess, 206.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 199.8ms
# Speed: 3.4ms preprocess, 199.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 255.2ms
# Speed: 2.0ms preprocess, 255.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 274.1ms
# Speed: 4.8ms preprocess, 274.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 238.5ms
# Speed: 0.5ms preprocess, 238.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.0ms
# Speed: 0.0ms preprocess, 210.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.8ms
# Speed: 4.0ms preprocess, 196.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.5ms
# Speed: 2.2ms preprocess, 190.5ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.0ms
# Speed: 2.0ms preprocess, 199.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.7ms
# Speed: 4.0ms preprocess, 197.7ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.4ms
# Speed: 2.5ms preprocess, 205.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.5ms
# Speed: 2.1ms preprocess, 205.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.2ms
# Speed: 2.7ms preprocess, 207.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.7ms
# Speed: 3.9ms preprocess, 203.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.7ms
# Speed: 2.8ms preprocess, 198.7ms inference, 12.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.8ms
# Speed: 2.5ms preprocess, 192.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.5ms
# Speed: 2.0ms preprocess, 201.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 223.9ms
# Speed: 3.0ms preprocess, 223.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.2ms
# Speed: 0.0ms preprocess, 212.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.4ms
# Speed: 2.8ms preprocess, 207.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.6ms
# Speed: 4.3ms preprocess, 206.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.1ms
# Speed: 3.0ms preprocess, 197.1ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.4ms
# Speed: 4.3ms preprocess, 196.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.5ms
# Speed: 0.0ms preprocess, 207.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.2ms
# Speed: 3.0ms preprocess, 199.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.6ms
# Speed: 4.7ms preprocess, 209.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.0ms
# Speed: 2.6ms preprocess, 207.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.5ms
# Speed: 0.0ms preprocess, 203.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.8ms
# Speed: 0.0ms preprocess, 209.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.5ms
# Speed: 4.1ms preprocess, 207.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.0ms
# Speed: 0.0ms preprocess, 211.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.9ms
# Speed: 4.3ms preprocess, 207.9ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.7ms
# Speed: 3.1ms preprocess, 205.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.3ms
# Speed: 4.3ms preprocess, 207.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.7ms
# Speed: 2.5ms preprocess, 206.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.8ms
# Speed: 3.1ms preprocess, 198.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.9ms
# Speed: 3.0ms preprocess, 201.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.5ms
# Speed: 2.8ms preprocess, 192.5ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.9ms
# Speed: 3.0ms preprocess, 198.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.9ms
# Speed: 2.0ms preprocess, 201.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.0ms
# Speed: 3.1ms preprocess, 206.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.4ms
# Speed: 4.3ms preprocess, 200.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.6ms
# Speed: 2.5ms preprocess, 210.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.4ms
# Speed: 2.0ms preprocess, 213.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.2ms
# Speed: 3.3ms preprocess, 203.2ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.3ms
# Speed: 4.1ms preprocess, 197.3ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.4ms
# Speed: 3.5ms preprocess, 207.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.9ms
# Speed: 4.2ms preprocess, 205.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.7ms
# Speed: 0.0ms preprocess, 210.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.3ms
# Speed: 3.3ms preprocess, 202.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 226.0ms
# Speed: 4.1ms preprocess, 226.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.0ms
# Speed: 2.9ms preprocess, 210.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.6ms
# Speed: 0.0ms preprocess, 206.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.0ms
# Speed: 5.6ms preprocess, 204.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.8ms
# Speed: 3.5ms preprocess, 201.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.2ms
# Speed: 3.5ms preprocess, 207.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.6ms
# Speed: 0.0ms preprocess, 205.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.0ms
# Speed: 3.2ms preprocess, 205.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.7ms
# Speed: 2.1ms preprocess, 207.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.6ms
# Speed: 3.0ms preprocess, 204.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.4ms
# Speed: 0.4ms preprocess, 203.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.9ms
# Speed: 0.0ms preprocess, 212.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.7ms
# Speed: 2.7ms preprocess, 203.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.2ms
# Speed: 4.3ms preprocess, 207.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.9ms
# Speed: 4.0ms preprocess, 215.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.7ms
# Speed: 0.0ms preprocess, 215.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.6ms
# Speed: 2.5ms preprocess, 201.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.2ms
# Speed: 2.5ms preprocess, 210.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.0ms
# Speed: 2.7ms preprocess, 200.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.1ms
# Speed: 4.0ms preprocess, 201.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.5ms
# Speed: 2.6ms preprocess, 206.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.7ms
# Speed: 0.0ms preprocess, 218.7ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.2ms
# Speed: 2.0ms preprocess, 203.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.6ms
# Speed: 3.0ms preprocess, 192.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.7ms
# Speed: 2.6ms preprocess, 203.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.0ms
# Speed: 2.1ms preprocess, 209.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 267.7ms
# Speed: 0.0ms preprocess, 267.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 247.5ms
# Speed: 4.6ms preprocess, 247.5ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.8ms
# Speed: 3.0ms preprocess, 213.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.6ms
# Speed: 0.0ms preprocess, 207.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.8ms
# Speed: 3.0ms preprocess, 214.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.1ms
# Speed: 0.0ms preprocess, 215.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.9ms
# Speed: 4.7ms preprocess, 202.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.7ms
# Speed: 3.0ms preprocess, 204.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.1ms
# Speed: 4.4ms preprocess, 199.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.3ms
# Speed: 0.0ms preprocess, 213.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.3ms
# Speed: 0.0ms preprocess, 207.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.6ms
# Speed: 2.1ms preprocess, 206.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.2ms
# Speed: 3.0ms preprocess, 204.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.2ms
# Speed: 3.1ms preprocess, 205.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.1ms
# Speed: 5.0ms preprocess, 199.1ms inference, 12.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.2ms
# Speed: 0.0ms preprocess, 197.2ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.6ms
# Speed: 0.0ms preprocess, 204.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.1ms
# Speed: 2.0ms preprocess, 200.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.5ms
# Speed: 2.0ms preprocess, 204.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.8ms
# Speed: 0.0ms preprocess, 209.8ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.7ms
# Speed: 3.2ms preprocess, 211.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.6ms
# Speed: 2.5ms preprocess, 212.6ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.4ms
# Speed: 3.1ms preprocess, 206.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.3ms
# Speed: 4.5ms preprocess, 198.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.3ms
# Speed: 3.5ms preprocess, 204.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.7ms
# Speed: 4.0ms preprocess, 200.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.2ms
# Speed: 3.0ms preprocess, 207.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.2ms
# Speed: 0.7ms preprocess, 200.2ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.5ms
# Speed: 3.0ms preprocess, 205.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.4ms
# Speed: 0.0ms preprocess, 211.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.3ms
# Speed: 3.1ms preprocess, 204.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.4ms
# Speed: 2.0ms preprocess, 205.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 216.9ms
# Speed: 2.8ms preprocess, 216.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.0ms
# Speed: 2.0ms preprocess, 199.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.6ms
# Speed: 1.0ms preprocess, 206.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.0ms
# Speed: 4.0ms preprocess, 202.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.1ms
# Speed: 2.1ms preprocess, 210.1ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.3ms
# Speed: 2.0ms preprocess, 197.3ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.3ms
# Speed: 0.0ms preprocess, 212.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.2ms
# Speed: 0.0ms preprocess, 215.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.7ms
# Speed: 3.1ms preprocess, 205.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.9ms
# Speed: 0.0ms preprocess, 210.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.0ms
# Speed: 3.0ms preprocess, 205.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.9ms
# Speed: 4.7ms preprocess, 197.9ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.9ms
# Speed: 3.1ms preprocess, 197.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.2ms
# Speed: 3.8ms preprocess, 202.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.3ms
# Speed: 3.3ms preprocess, 198.3ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.1ms
# Speed: 5.1ms preprocess, 208.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.1ms
# Speed: 3.3ms preprocess, 205.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.0ms
# Speed: 0.0ms preprocess, 209.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.4ms
# Speed: 2.0ms preprocess, 209.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.1ms
# Speed: 2.0ms preprocess, 204.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.1ms
# Speed: 0.0ms preprocess, 212.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.5ms
# Speed: 2.0ms preprocess, 202.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.1ms
# Speed: 4.7ms preprocess, 197.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 226.7ms
# Speed: 3.3ms preprocess, 226.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.1ms
# Speed: 3.7ms preprocess, 204.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.4ms
# Speed: 3.8ms preprocess, 210.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.8ms
# Speed: 2.8ms preprocess, 195.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.3ms
# Speed: 0.0ms preprocess, 204.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.6ms
# Speed: 4.7ms preprocess, 195.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.6ms
# Speed: 1.7ms preprocess, 204.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.8ms
# Speed: 2.8ms preprocess, 207.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.8ms
# Speed: 0.0ms preprocess, 206.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.0ms
# Speed: 4.4ms preprocess, 209.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.3ms
# Speed: 3.4ms preprocess, 196.3ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.9ms
# Speed: 3.1ms preprocess, 206.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.4ms
# Speed: 0.0ms preprocess, 210.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.0ms
# Speed: 0.0ms preprocess, 212.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.3ms
# Speed: 3.7ms preprocess, 197.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 248.1ms
# Speed: 3.0ms preprocess, 248.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 244.3ms
# Speed: 2.5ms preprocess, 244.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.3ms
# Speed: 3.5ms preprocess, 220.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.0ms
# Speed: 4.0ms preprocess, 207.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.5ms
# Speed: 2.0ms preprocess, 205.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.8ms
# Speed: 3.0ms preprocess, 206.8ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.2ms
# Speed: 5.1ms preprocess, 207.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.1ms
# Speed: 2.0ms preprocess, 210.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.7ms
# Speed: 4.6ms preprocess, 206.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.8ms
# Speed: 3.0ms preprocess, 208.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.3ms
# Speed: 3.2ms preprocess, 204.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.5ms
# Speed: 4.9ms preprocess, 215.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.5ms
# Speed: 3.0ms preprocess, 205.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.4ms
# Speed: 2.0ms preprocess, 211.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.9ms
# Speed: 3.0ms preprocess, 194.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.1ms
# Speed: 5.6ms preprocess, 195.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.9ms
# Speed: 3.4ms preprocess, 205.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.9ms
# Speed: 0.0ms preprocess, 200.9ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.1ms
# Speed: 3.2ms preprocess, 204.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.1ms
# Speed: 2.0ms preprocess, 211.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.3ms
# Speed: 0.0ms preprocess, 209.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.3ms
# Speed: 3.8ms preprocess, 211.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.5ms
# Speed: 2.3ms preprocess, 201.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.4ms
# Speed: 1.0ms preprocess, 212.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.8ms
# Speed: 3.6ms preprocess, 208.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.4ms
# Speed: 0.0ms preprocess, 202.4ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.4ms
# Speed: 3.0ms preprocess, 209.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.2ms
# Speed: 2.1ms preprocess, 211.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.5ms
# Speed: 3.4ms preprocess, 209.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.3ms
# Speed: 2.1ms preprocess, 222.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.5ms
# Speed: 2.5ms preprocess, 208.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.9ms
# Speed: 3.3ms preprocess, 206.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.0ms
# Speed: 3.4ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.6ms
# Speed: 2.3ms preprocess, 209.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.0ms
# Speed: 3.5ms preprocess, 215.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.1ms
# Speed: 4.3ms preprocess, 200.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.8ms
# Speed: 3.1ms preprocess, 211.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.9ms
# ...
#
# 0: 480x640 2 persons, 227.2ms
# Speed: 2.1ms preprocess, 227.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 242.7ms
# Speed: 3.6ms preprocess, 242.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 304.4ms
# Speed: 4.0ms preprocess, 304.4ms inference, 15.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 287.0ms
# Speed: 4.5ms preprocess, 287.0ms inference, 18.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 270.5ms
# Speed: 0.0ms preprocess, 270.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 255.4ms
# Speed: 5.1ms preprocess, 255.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 256.1ms
# Speed: 4.0ms preprocess, 256.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 224.5ms
# Speed: 3.3ms preprocess, 224.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 233.8ms
# Speed: 3.6ms preprocess, 233.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 217.7ms
# Speed: 3.0ms preprocess, 217.7ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 268.2ms
# Speed: 5.0ms preprocess, 268.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 268.4ms
# Speed: 3.4ms preprocess, 268.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 280.3ms
# Speed: 5.2ms preprocess, 280.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 302.1ms
# Speed: 0.0ms preprocess, 302.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 247.3ms
# Speed: 0.0ms preprocess, 247.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 249.8ms
# Speed: 5.1ms preprocess, 249.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 240.3ms
# Speed: 4.3ms preprocess, 240.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 277.5ms
# Speed: 3.0ms preprocess, 277.5ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 258.1ms
# Speed: 4.5ms preprocess, 258.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 241.1ms
# Speed: 0.0ms preprocess, 241.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 253.9ms
# Speed: 4.6ms preprocess, 253.9ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 220.0ms
# Speed: 4.1ms preprocess, 220.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 282.9ms
# Speed: 3.5ms preprocess, 282.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 229.5ms
# Speed: 3.7ms preprocess, 229.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 319.8ms
# Speed: 4.8ms preprocess, 319.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 295.0ms
# Speed: 4.1ms preprocess, 295.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 292.4ms
# Speed: 2.0ms preprocess, 292.4ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 248.5ms
# Speed: 0.0ms preprocess, 248.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 249.1ms
# Speed: 3.5ms preprocess, 249.1ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 205.8ms
# Speed: 4.8ms preprocess, 205.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 229.4ms
# Speed: 1.6ms preprocess, 229.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 214.7ms
# Speed: 2.5ms preprocess, 214.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 217.8ms
# Speed: 4.1ms preprocess, 217.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 486.5ms
# Speed: 5.2ms preprocess, 486.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 289.3ms
# Speed: 2.5ms preprocess, 289.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 272.2ms
# Speed: 2.1ms preprocess, 272.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 241.1ms
# Speed: 5.5ms preprocess, 241.1ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 252.6ms
# Speed: 4.1ms preprocess, 252.6ms inference, 10.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 289.2ms
# Speed: 0.0ms preprocess, 289.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 290.3ms
# Speed: 2.1ms preprocess, 290.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 257.0ms
# Speed: 4.1ms preprocess, 257.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.0ms
# Speed: 4.6ms preprocess, 224.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.8ms
# Speed: 2.5ms preprocess, 227.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 221.8ms
# Speed: 0.0ms preprocess, 221.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 231.8ms
# Speed: 0.0ms preprocess, 231.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 246.8ms
# Speed: 1.5ms preprocess, 246.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 247.4ms
# Speed: 0.0ms preprocess, 247.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 297.3ms
# Speed: 0.0ms preprocess, 297.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 343.5ms
# Speed: 3.0ms preprocess, 343.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 302.6ms
# Speed: 0.0ms preprocess, 302.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.6ms
# Speed: 0.0ms preprocess, 250.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 246.2ms
# Speed: 4.5ms preprocess, 246.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 245.3ms
# Speed: 3.0ms preprocess, 245.3ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 254.5ms
# Speed: 2.6ms preprocess, 254.5ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 285.0ms
# Speed: 3.6ms preprocess, 285.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 260.7ms
# Speed: 0.0ms preprocess, 260.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 230.8ms
# Speed: 4.6ms preprocess, 230.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.0ms
# Speed: 4.0ms preprocess, 250.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 236.6ms
# Speed: 2.0ms preprocess, 236.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 239.8ms
# Speed: 5.1ms preprocess, 239.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 226.4ms
# Speed: 3.0ms preprocess, 226.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 281.9ms
# Speed: 2.0ms preprocess, 281.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 327.8ms
# Speed: 3.0ms preprocess, 327.8ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 304.8ms
# Speed: 0.0ms preprocess, 304.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 283.1ms
# Speed: 0.0ms preprocess, 283.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 311.6ms
# Speed: 0.0ms preprocess, 311.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 232.6ms
# Speed: 4.8ms preprocess, 232.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 232.2ms
# Speed: 4.2ms preprocess, 232.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 246.1ms
# Speed: 6.6ms preprocess, 246.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 248.6ms
# Speed: 3.0ms preprocess, 248.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 254.1ms
# Speed: 3.0ms preprocess, 254.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 248.3ms
# Speed: 3.8ms preprocess, 248.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 246.1ms
# Speed: 4.0ms preprocess, 246.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 226.1ms
# Speed: 5.1ms preprocess, 226.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 255.9ms
# Speed: 0.0ms preprocess, 255.9ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 221.7ms
# Speed: 0.0ms preprocess, 221.7ms inference, 13.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 273.6ms
# Speed: 0.0ms preprocess, 273.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 270.3ms
# Speed: 3.0ms preprocess, 270.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 264.0ms
# Speed: 5.7ms preprocess, 264.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.2ms
# Speed: 3.0ms preprocess, 219.2ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 273.4ms
# Speed: 0.0ms preprocess, 273.4ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.1ms
# Speed: 3.0ms preprocess, 210.1ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 253.8ms
# Speed: 3.4ms preprocess, 253.8ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 243.6ms
# Speed: 0.0ms preprocess, 243.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 290.1ms
# Speed: 0.0ms preprocess, 290.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 288.4ms
# Speed: 0.0ms preprocess, 288.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 256.3ms
# Speed: 2.5ms preprocess, 256.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.9ms
# Speed: 4.6ms preprocess, 235.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 240.7ms
# Speed: 0.1ms preprocess, 240.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 236.3ms
# Speed: 0.0ms preprocess, 236.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 242.0ms
# Speed: 0.0ms preprocess, 242.0ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 225.1ms
# Speed: 0.0ms preprocess, 225.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 297.0ms
# Speed: 3.0ms preprocess, 297.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 304.8ms
# Speed: 4.0ms preprocess, 304.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 261.2ms
# Speed: 5.1ms preprocess, 261.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 281.4ms
# Speed: 0.0ms preprocess, 281.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.5ms
# Speed: 4.0ms preprocess, 213.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.6ms
# Speed: 0.0ms preprocess, 224.6ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.4ms
# Speed: 4.0ms preprocess, 250.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 261.5ms
# Speed: 0.0ms preprocess, 261.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 276.7ms
# Speed: 2.5ms preprocess, 276.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 249.0ms
# Speed: 0.0ms preprocess, 249.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 237.6ms
# Speed: 0.0ms preprocess, 237.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 223.7ms
# Speed: 1.3ms preprocess, 223.7ms inference, 15.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.2ms
# Speed: 5.0ms preprocess, 235.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 271.1ms
# Speed: 4.1ms preprocess, 271.1ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 282.5ms
# Speed: 5.6ms preprocess, 282.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 262.1ms
# Speed: 0.0ms preprocess, 262.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 238.6ms
# Speed: 3.0ms preprocess, 238.6ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 365.5ms
# Speed: 5.0ms preprocess, 365.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 262.8ms
# Speed: 5.1ms preprocess, 262.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 273.9ms
# Speed: 0.0ms preprocess, 273.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.5ms
# Speed: 0.0ms preprocess, 250.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 282.0ms
# Speed: 0.0ms preprocess, 282.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 289.8ms
# Speed: 4.0ms preprocess, 289.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.7ms
# Speed: 0.0ms preprocess, 250.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 238.8ms
# Speed: 0.0ms preprocess, 238.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 231.6ms
# Speed: 3.2ms preprocess, 231.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 237.8ms
# Speed: 0.0ms preprocess, 237.8ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.5ms
# Speed: 3.0ms preprocess, 227.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 261.3ms
# Speed: 0.0ms preprocess, 261.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 275.0ms
# Speed: 2.0ms preprocess, 275.0ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 256.6ms
# Speed: 0.0ms preprocess, 256.6ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 276.7ms
# Speed: 5.1ms preprocess, 276.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
'''
Function to create a local coordinate system
'''
def relative_pos(o,p2,p3):
    p2=np.array(o)-np.array(p2)
    p3=np.array(o)-np.array(p3)
    return (p2,p3)

'''
Function to calculate angle between two vectors
'''
def angle_between(v1, v2):
  cos_theta = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))
  return np.degrees(np.arccos(np.clip(cos_theta, -1.0, 1.0)))

'''
Function to estimate whether a person is a threat or not
based on location of his joints
'''
def estimate_threat(kypts):
    flag=False
    kypts=[[x,y] if p>0.5 else [0,0] for x,y,p in kypts]
    rs,ls=kypts[6],kypts[5] #shoulders c,y coord
    rw,lw=kypts[10],kypts[9] #wrist x,y coord
    rel,lel=kypts[8],kypts[7] #elbow x,y coord
    
    '''
    Check if any of the wrist is raised above the elbow level and the angle 
    formed between the shoulder and hand of the respective hand is greater than 90
    then we may consider it as a threating gesture.
    '''
    if (rel!=[0,0]) & (rs!=[0,0]) & (rw!=[0,0]):
        if rw[1]<=rel[1]:
            p1,q1=relative_pos(rel,rw,rs)
            angle=angle_between(q1,p1)
            if angle>90:
                flag=True
                return flag
    if (lel!=[0,0]) & (ls!=[0,0]) & (lw!=[0,0]):
        if lw[1]<=lel[1]:
            p1,q1=relative_pos(lel,lw,ls)
            angle=angle_between(q1,p1)
            if angle>90:
                flag=True
                return flag
    return flag


# Load the YOLOv8-pose model for object detection & gathering coordinate data of joints
pose_model=YOLO('yolov8n-pose.pt')

# Create a tracker object of DeepSORT
tracker=Tracker()

# List of random colors (BGR)
colors=[(random.randint(0,255),random.randint(0,255),random.randint(0,200)) for j in range(10)]

# Load input file
success, frame= cap.read()
video_path = "robbery2.mp4"
cap = cv2.VideoCapture(video_path)
success, frame= cap.read()
sav = cv2.VideoWriter('videoplayback_out.mp4',  
                         cv2.VideoWriter_fourcc(*'MP4V'), 
                         cap.get(cv2.CAP_PROP_FPS),(frame.shape[1],frame.shape[0]))

while cap.isOpened():
     success, frame= cap.read()
     if success:
          results=pose_model(frame,conf=0.2,classes=[0],show=False)
          detections=[]
          font = cv2.FONT_HERSHEY_SIMPLEX
          try:
             for result in results:
               for r,pr in zip(result.boxes.data.tolist(),result.keypoints.data.tolist()):
                    x1,y1,x2,y2,probs,cls=r
                    x1=int(x1)
                    y1=int(y1)
                    x2=int(x2)
                    y2=int(y2)
                    cls=int(cls)
                    detections.append([x1,y1,x2,y2,probs])
                    threat=estimate_threat(pr)
                    if threat:
                        cv2.putText(frame,'THREAT',(int(x1) , int(y1)),font,0.5,(0,0,255),3,cv2.LINE_AA)
                    else:
                        cv2.putText(frame,'SAFE',(int(x1) , int(y1)),font,0.5,(0,255,0),3,cv2.LINE_AA)

               tracker.update(frame,detections)
               for track in tracker.tracks:
                    x1,y1,x2,y2=track.bbox
                    id=track.track_id
                    cv2.rectangle(frame,(int(x1) , int(y1)),(int(x2) , int(y2)), 
                            (colors[id % len(colors)]),3)
                         
          except Exception as e:
               cap.release()
               cv2.destroyAllWindows()
               raise e
          
          sav.write(frame) 

          if cv2.waitKey(1) & 0xFF == ord("q"):
                    break
     else:
          print('Failed!!')
cap.release()
sav.release()
cv2.destroyAllWindows()

# %%
cap.release()
sav.release()
cv2.destroyAllWindows()
